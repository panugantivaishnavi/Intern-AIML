# %% [markdown]
# # Internship
# ## P.Bhanu Vaishnavi
# ## Day 08
# ## Date:1st,June,19)

# %%
import pandas as pd
import numpy as np
def readcsv(filename):
    df=pd.read_csv(filename)
    return df
readcsv('data/Ball_By_Ball.csv')
# Out:
#         MatcH_id  Over_id  Ball_id  Innings_No Team_Batting Team_Bowling  \
# 0         598028       15        6           1            5            2
# 1         598028       14        1           1            5            2
# 2         598028       14        2           1            5            2
# 3         598028       14        3           1            5            2
# 4         598028       14        4           1            5            2
# 5         598028       14        5           1            5            2
# 6         598028       14        6           1            5            2
# 7         598028       13        1           1            5            2
# 8         598028       13        2           1            5            2
# 9         598028       13        3           1            5            2
# 10        598028       13        4           1            5            2
# 11        598028       13        5           1            5            2
# ...

# %%
How many runs of Dhoni On 4/23/2008 Chennai Super Kings vs Mumbai Indians Match ( Use Oops concepts)

# %%
import pandas as pd
import numpy as np
def readcsv(filename):
    df=pd.read_csv(filename)
    return df
readcsv('data/newmatch.csv')
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# 5           5    335992             Rajasthan Royals
# 6           6    335993              Deccan Chargers
# 7           7    335994          Chennai Super Kings
# 8           8    335995              Deccan Chargers
# 9           9    335996              Kings XI Punjab
# 10         10    335997  Royal Challengers Bangalore
# 11         11    335998          Chennai Super Kings
# 12         12    335999               Mumbai Indians
# 13         13    336000              Kings XI Punjab
# 14         14    336001  Royal Challengers Bangalore
# 15         15    336002        Kolkata Knight Riders
# 16         16    336003             Delhi Daredevils
# ...

# %%
import pandas as pd
import numpy as np
def readcsv(filename):
    df=pd.read_csv(filename)
    return df
readcsv('data/Player.csv')
# Out:
#      PLAYER_SK  Player_Id        Player_Name         DOB     Batting_hand  \
# 0            0          1         SC Ganguly    7/8/1972    Left-hand bat
# 1            1          2        BB McCullum   9/27/1981   Right-hand bat
# 2            2          3         RT Ponting  12/19/1974   Right-hand bat
# 3            3          4          DJ Hussey   7/15/1977   Right-hand bat
# 4            4          5    Mohammad Hafeez  10/17/1980   Right-hand bat
# 5            5          6           R Dravid   1/11/1973   Right-hand bat
# 6            6          7           W Jaffer   2/16/1978   Right-hand bat
# 7            7          8            V Kohli   11/5/1988   Right-hand bat
# 8            8          9          JH Kallis  10/16/1975   Right-hand bat
# 9            9         10           CL White   8/18/1983   Right-hand bat
# 10          10         11         MV Boucher   12/3/1976   Right-hand bat
# 11          11         12            B Akhil   10/7/1977   Right-hand bat
# ...

# %%
import pandas as pd
import numpy as np
def readcsv(filename):
    df=pd.read_csv(filename)
    return df
readcsv('data/Player_match.csv')
# Out:
#        Player_match_SK  PlayerMatch_key  Match_Id  Player_Id  \
# 0                   -1               -1        -1         -1
# 1                12694      33598700006    335987          6
# 2                12695      33598700007    335987          7
# 3                12696      33598700008    335987          8
# 4                12697      33598700009    335987          9
# 5                12698      33598700010    335987         10
# 6                12699      33598700011    335987         11
# 7                12700      33598700012    335987         12
# 8                12701      33598700013    335987         13
# 9                12702      33598700014    335987         14
# 10               12703      33598700015    335987         15
# 11               12704      33598700016    335987         16
# 12               12705      33598700001    335987          1
# 13               12706      33598700002    335987          2
# ...

# %%
import pandas as pd
import numpy as np
def readcsv(filename):
    df=pd.read_csv(filename)
    return df
readcsv('data/Team.csv')
# Out:
#     Team_SK  Team_Id                    Team_Name
# 0         0        1        Kolkata Knight Riders
# 1         1        2  Royal Challengers Bangalore
# 2         2        3          Chennai Super Kings
# 3         3        4              Kings XI Punjab
# 4         4        5             Rajasthan Royals
# 5         5        6             Delhi Daredevils
# 6         6        7               Mumbai Indians
# 7         7        8              Deccan Chargers
# 8         8        9         Kochi Tuskers Kerala
# 9         9       10                Pune Warriors
# 10       10       11          Sunrisers Hyderabad
# 11       11       12      Rising Pune Supergiants
# 12       12       13                Gujarat Lions

# %%
## Problem 2:
### Problen Statement: How many runs of Dhoni On 4/23/2008 Chennai Super Kings vs Mumbai Indians Match ( Use Oops concepts)

# %%
import matplotlib.pyplot as plt
import pandas as pd
class DataList:
    def data_list1(self,filename):
        d=pd.read_csv(filename)
        return d
    def compare(self,df,tm1,tm2,date):
        for i in df.values:
            if(i[2]==tm1 and i[3]==tm2 and i[4]==date):
                return i[1]
    def compare1(df1,name):
        for i in df1.values:
            if(i[2]==name ):
                return i[1]
    def Runs(df2,matchid,plyerid,date):
        sum=0
        for i in df2.values:
            if(i[0]==matchid and i[27]==date and i[29]==plyerid):
                sum=sum+i[8]
        print('Runs of Dhoni On 4/23/2008 Chennai Super Kings vs Mumbai Indians Match :',sum)
dl=DataList()
df=dl.data_list1('data/Match.csv')
df1=dl.data_list1('data/Player.csv')
df2=dl.data_list1('data/Ball_By_Ball.csv')
matchId=dl.compare(df,'Chennai Super Kings','Mumbai Indians','4/23/2008')
playerId=DataList.compare1(df1,'MS Dhoni')
run=DataList.Runs(df2,matchId,playerId,'4/23/2008')
# Out:
# Runs of Dhoni On 4/23/2008 Chennai Super Kings vs Mumbai Indians Match : 30

# %%
## Problem 2:
### Problem Statement:  4/23/2008  Chennai Super Kings vs Mumbai Indians Match
Plot a bar graph for all the players in the   Mumbai Indians  team

# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np 
class DataList:
    def data_list1(s,filename):
        d=pd.read_csv(filename)
        return d
    def compar(s,df,tm1,tm2,data):
        for i in df.values:
            if(i[2]==tm1 and i[3]==tm2 and i[4]==data):
                return i[1]
    def compar1(s,df3,a,b):
        l1=[]
        for i in df3.values:
            if(i[2]==b and i[10]==a):
                l1.append(i[4])
        return l1
    def compar2(s,df1,name):
        l3=[]
        for j in range(0,len(playerList)):
            for i in df1.values:
                if(i[2]==playerList[j]):
                    l3.append(i[1])
        return l3
    def Runs(s,df2,matchid,plyerid,date):
        l4=[]
        for j in range (0,len(plyerid)):
            sum=0
            for i in df2.values:
                if(i[0]==matchid  and i[29]==plyerid[j] and i[27]==date):
                    sum=sum+i[8]
            l4.append(sum)
        return l4
    def bar_graph(s,plyerlist,runs):
        x=1/2
        plt.bar(plyerlist,runs,x,color=('Black','Purple','Red'))
        plt.rcParams['figure.figsize']=[20,20]
        plt.xlabel('PlayerList')
        plt.ylabel('Runs')
        plt.title('Bar graph for all the players in the Mumbai Indians team')
        plt.show
dl=DataList()
df=dl.data_list1('data/Match.csv')
df1=dl.data_list1('data/Player.csv')
df2=dl.data_list1('data/Ball_By_Ball.csv')
df3=dl.data_list1('data/Player_match.csv')
df4=dl.data_list1('data/team.csv')
matchId=dl.compar(df,'Chennai Super Kings','Mumbai Indians','4/23/2008')
playerList=dl.compar1(df3,'Mumbai Indians',matchId)
playerId=dl.compar2(df1,playerList)
run=dl.Runs(df2,matchId,playerId,'4/23/2008')
dl.bar_graph(playerList,run)
